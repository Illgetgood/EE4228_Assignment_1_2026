# %%
# !apt-get update
# !apt-get install -y libopencv-dev
# !pip install gdown
# !pip install opencv-contrib-python pillow numpy
# Out:
# Get:1 https://cli.github.com/packages stable InRelease [3,917 B]
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Hit:3 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:4 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:5 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:7 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ Packages [88.5 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:9 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [10.0 MB]
# Get:10 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease [18.1 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [7,143 kB]
# Hit:12 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# ...

# %%
# !git clone https://github.com/Illgetgood/EE4228_Assignment_1_2026.git
# Out:
# Cloning into 'EE4228_Assignment_1_2026'...
# remote: Enumerating objects: 60, done.
# remote: Counting objects: 100% (60/60), done.
# remote: Compressing objects: 100% (60/60), done.
# remote: Total 60 (delta 25), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (60/60), 52.32 MiB | 10.42 MiB/s, done.
# Resolving deltas: 100% (25/25), done.

# %%
# %cd EE4228_Assignment_1_2026
# !mkdir dataset
# Out:
# /content/EE4228_Assignment_1_2026

# %%
# !wget https://raw.githubusercontent.com/kurnianggoro/GSOC2017/master/data/lbfmodel.yaml
# Out:
# --2026-04-13 12:17:31--  https://raw.githubusercontent.com/kurnianggoro/GSOC2017/master/data/lbfmodel.yaml
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 56375857 (54M) [text/plain]
# Saving to: ‘lbfmodel.yaml’
#
# lbfmodel.yaml       100%[===================>]  53.76M   134MB/s    in 0.4s
#
# 2026-04-13 12:17:34 (134 MB/s) - ‘lbfmodel.yaml’ saved [56375857/56375857]

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# !unzip "/content/drive/MyDrive/EE4228_LDA_face_recognition/Members Face-20260413T015558Z-3-001.zip" -d dataset
# Out:
# Archive:  /content/drive/MyDrive/EE4228_LDA_face_recognition/Members Face-20260413T015558Z-3-001.zip
#   inflating: dataset/Members Face/Ivo/20260226_171509_104576_0008.jpg
#   inflating: dataset/Members Face/Haechan/20260302_170251_753024_0006.jpg
#   inflating: dataset/Members Face/Ivo/20260226_171500_694380_0001.jpg
#   inflating: dataset/Members Face/An/IMG_1099.JPG
#   inflating: dataset/Members Face/Ivo/20260226_171513_322979_0011.jpg
#   inflating: dataset/Members Face/Haechan/20260302_170254_208964_0007.jpg
#   inflating: dataset/Members Face/Ereston/IMG_1344.JPG
#   inflating: dataset/Members Face/Ivo/20260226_171510_724066_0009.jpg
#   inflating: dataset/Members Face/Ivo/20260226_171503_397760_0002.jpg
#   inflating: dataset/Members Face/Haechan/20260302_170247_691205_0005.jpg
#   inflating: dataset/Members Face/An/IMG_1102.JPG
#   inflating: dataset/Members Face/Ivo/20260226_171512_015330_0010.jpg
#   inflating: dataset/Members Face/An/IMG_1101.JPG
# ...

# %%
# Copy all the output to member.txt inside folder dataset/Members Face
# !python create_csv.py ./dataset/Members\ Face
# Out:
# ./dataset/Members Face/An/IMG_1097.JPG;1
# ./dataset/Members Face/An/IMG_1095.JPG;1
# ./dataset/Members Face/An/IMG_1100.JPG;1
# ./dataset/Members Face/An/IMG_1098.JPG;1
# ./dataset/Members Face/An/IMG_1102.JPG;1
# ./dataset/Members Face/An/20260323_145008.jpg;1
# ./dataset/Members Face/An/IMG_1094.JPG;1
# ./dataset/Members Face/An/IMG_1096.JPG;1
# ./dataset/Members Face/An/IMG_20260323_163445.jpg;1
# ./dataset/Members Face/An/IMG_1099.JPG;1
# ./dataset/Members Face/An/IMG_20260323_163443.jpg;1
# ./dataset/Members Face/An/IMG_1103.JPG;1
# ./dataset/Members Face/An/IMG_1101.JPG;1
# ./dataset/Members Face/Edward/IMG_1246.JPG;2
# ./dataset/Members Face/Edward/IMG_1084.JPG;2
# ./dataset/Members Face/Edward/IMG_1093.JPG;2
# ./dataset/Members Face/Edward/IMG_1090.JPG;2
# ./dataset/Members Face/Edward/IMG_1089.JPG;2
# ./dataset/Members Face/Edward/IMG_1086.JPG;2
# ./dataset/Members Face/Edward/IMG_1244.JPG;2
# ./dataset/Members Face/Edward/IMG_1243.JPG;2
# ...

# %%
# !python create_modified_faces.py
# Out:
# loading data from : lbfmodel.yaml
# Processed: IMG_1097
# Processed: IMG_1095
# Processed: IMG_1100
# Processed: IMG_1098
# Processed: IMG_1102
# Processed: 20260323_145008
# Processed: IMG_1094
# Processed: IMG_1096
# Processed: IMG_20260323_163445
# Processed: IMG_1099
# Processed: IMG_20260323_163443
# Processed: IMG_1103
# Processed: IMG_1101
# Processed: IMG_1246
# Processed: IMG_1084
# Processed: IMG_1093
# Processed: IMG_1090
# Processed: IMG_1089
# Processed: IMG_1086
# Processed: IMG_1244
# Processed: IMG_1243
# Processed: IMG_1088
# Processed: IMG_1120
# Processed: IMG_1091
# Processed: IMG_1242
# Processed: IMG_1241
# Processed: IMG_1119
# Processed: 20260302_201622_912960_0014
# Processed: 20260302_201630_709777_0020
# Processed: 20260302_201627_630925_0018
# Processed: IMG_1344
# Processed: 20260302_201626_551598_0017
# Processed: 20260302_201628_714310_0019
# Processed: IMG_1347
# Processed: IMG_1345
# Processed: IMG_1348
# Processed: 20260302_201624_293762_0015
# ...

# %%
# Copy all the output to member_modified.txt inside folder dataset/Members Face/modified
# !python create_csv.py ./dataset/Members\ Face/modified
# Out:
# ./dataset/Members Face/modified/An/IMG_20260323_163443_30_30_200_200.jpg;0
# ./dataset/Members Face/modified/An/IMG_1098_30_30_200_200.jpg;0
# ./dataset/Members Face/modified/An/IMG_1101_30_30_200_200.jpg;0
# ./dataset/Members Face/modified/An/IMG_1099_30_30_200_200.jpg;0
# ./dataset/Members Face/modified/An/IMG_1094_30_30_200_200.jpg;0
# ./dataset/Members Face/modified/An/IMG_1102_30_30_200_200.jpg;0
# ./dataset/Members Face/modified/An/IMG_1095_30_30_200_200.jpg;0
# ./dataset/Members Face/modified/An/20260323_145008_30_30_200_200.jpg;0
# ./dataset/Members Face/modified/An/IMG_1100_30_30_200_200.jpg;0
# ./dataset/Members Face/modified/An/IMG_1097_30_30_200_200.jpg;0
# ./dataset/Members Face/modified/An/IMG_1096_30_30_200_200.jpg;0
# ./dataset/Members Face/modified/An/IMG_1103_30_30_200_200.jpg;0
# ./dataset/Members Face/modified/An/IMG_20260323_163445_30_30_200_200.jpg;0
# ./dataset/Members Face/modified/Edward/IMG_1090_30_30_200_200.jpg;1
# ...

# %%
# !python fisher_opencv.py dataset/Members\ Face/modified/member_modified.txt output/member/fisher
# Out:
# --- Training Set Accuracy ---
#   An           | 13 / 13 correct (100%)
#   Edward       | 14 / 14 correct (100%)
#   Ereston      | 12 / 12 correct (100%)
#   Haechan      | 10 / 10 correct (100%)
#   Ivo          | 11 / 11 correct (100%)
#   Nam          | 10 / 10 correct (100%)
#   TOTAL        | 70 / 70 correct (100%)
#   NOTE: Low training accuracy = bad data quality or too few images per person.
# ----------------------------
#
# Predicted class = 5 / Actual class = 5.
# Eigenvalue #0 = 9248.13272
# Eigenvalue #1 = 202.21202
# Eigenvalue #2 = 144.59707
# Eigenvalue #3 = 73.09570
# Eigenvalue #4 = 7.05484
#
# --- Per-Person Distance Statistics (held-out 20%, lower = closer) ---
#   An           | min:   183.3  mean:   196.6  max:   209.9  stddev:   13.3  (n=2)
#   Edward       | min:   391.0  mean:   433.9  max:   476.7  stddev:   42.9  (n=2)
#   Ereston      | min:   721.7  mean:   751.7  max:   781.8  stddev:   30.1  (n=2)
# ...
